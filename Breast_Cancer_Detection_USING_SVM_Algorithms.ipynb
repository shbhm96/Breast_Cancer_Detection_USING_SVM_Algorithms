# %% [markdown]
# <a href="https://colab.research.google.com/github/shbhm96/Breast_Cancer_Detection_USING_SVM_Algorithms/blob/main/Breast_Cancer_Detection_USING_SVM_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import datasets, svm
from sklearn.preprocessing import StandardScaler

# %%
cancer =  datasets.load_breast_cancer()
df = pd.DataFrame(np.c_[cancer['data'],cancer['target']])
columns = np.append(cancer['feature_names'],['target'])
df.head()
# Out:
#       0      1       2       3        4        5       6        7       8   \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         9   ...     21      22      23      24      25      26      27  \
# 0  0.07871  ...  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        28       29   30
# 0  0.4601  0.11890  0.0
# 1  0.2750  0.08902  0.0
# ...

# %%
Xval = df.iloc[:,0:-1]
yval = df.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(Xval, yval, test_size=0.2, random_state=3)

# %%
scs = StandardScaler()
x_train = scs.fit_transform(x_train)
x_test = scs.transform(x_test)

# %%
#Create a SVM Classifier
clfsvm = svm.SVC(kernel='linear')

# %%
#Train thev model
clfsvm.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#Predict the response
y_pred = clfsvm.predict(x_test)
